# %% [markdown]
# # COSC Learning Lab: 01_inventory_json.py

# %% [markdown]
# Related:
# * [01_inventory.py](01_inventory.ipynb)
# * [01_inventory_mounted.py](01_inventory_mounted.ipynb)
# * [01_inventory_summary.py](Inventory.ipynb#01_inventory_summary.py)

# %%
from importlib import import_module
help(import_module('01_inventory_json', 'learning_lab'))
# Out:
# Help on module 01_inventory_json:
#
# NAME
#     01_inventory_json - Sample usage of function 'inventory_json'.
#
# FILE
#     /home/virl/git/cosc-learning-labs/src/learning_lab/01_inventory_json.py
#
# DESCRIPTION
#     Demonstrate how to process JSON.
#     The function output is 'reduced' to provide a summary.
#     The summary is comparable to function inventory_summary().
#
# FUNCTIONS
#     main()

# %%
run 01_inventory_json
# Out:
# Python Library Documentation: function inventory_json in module basics.inventory
#
# inventory_json()
#     Return a list of inventory items in JSON representation.
#
# JSON processed into inventory summary:
# (<name>, <connected>, <capabilities>)
# (u'openflow:1', False, 0)
# (u'xrvr-1', True, 131)
# (u'xrvr-2', True, 131)
# (u'controller-config', True, 182)
# (u'unreachable', False, 0)
# (u'xrvr-999', False, 0)
# (u'openflow:2', False, 0)
# (u'openflow:3', False, 0)

# %%
from basics.odl_http import http_history
from basics.http import http_history_to_html
from IPython.core.display import HTML
HTML(http_history_to_html(http_history()))
# Out:
# <table>
#   <style>table {border: 1px solid black;}</style>
#   <style>tr:nth-of-type(even) {background-color:#eee;}</style>
#   <style>tr:nth-of-type(odd) {background-color:#fff;}</style>
#   <style>th {background-color:lightgray;}</style>
#   <thead>
#     <tr>
#       <th style="text-align:center" colspan="2">Request</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Method</th>
#       <td>GET</td>
#     </tr>
#     <tr>
#       <th>URL</th>
#       <td>http://127.0.0.1:8181/restconf/operational/opendaylight-inventory:nodes</td>
#     </tr>
#     <tr>
#       <th>Headers</th>
#       <td><table>
#     <tr>
#         <td>
#             Authorization
#         </td>
#         <td>
#             Basic YWRtaW46YWRtaW4=
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Accept-Encoding
#         </td>
#         <td>
#             gzip, deflate, compress
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Accept
#         </td>
# ...
