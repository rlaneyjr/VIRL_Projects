# %% [markdown]
# #COSC Learning Lab

# %% [markdown]
# ##03_interface_configuration.py

# %% [markdown]
# Related Scripts:
# * [03_interface_names.py](03_interface_names.ipynb)
# * [03_interface_properties.py](03_interface_properties.ipynb)
# * [03_interface_configuration_update.py](03_interface_configuration_update.ipynb)

# %% [markdown]
# ###Table of Contents

# %% [markdown]
# * [Table of Contents](#Table-of-Contents)
# * [Documentation](#Documentation)
# * [Implementation](#Implementation)
# * [Execution](#Execution)
# * [HTTP](#HTTP)

# %% [markdown]
# ###Documentation

# %%
help('learning_lab.03_interface_configuration')
# Out:
# Help on module learning_lab.03_interface_configuration in learning_lab:
#
# NAME
#     learning_lab.03_interface_configuration - Sample usage of function 'interface_configuration'.
#
# DESCRIPTION
#     Print the function's documentation then invoke the function and print the output.
#     Apply the function to one interface on one device.
#     The selected device must be connected.
#     The selected interface is on the 'data plane'
#     Interfaces on the 'control plane' are excluded.
#
# FUNCTIONS
#     demonstrate(device_name, interface_name)
#         Apply function 'interface_configuration' to the specified device/interface.
#
#     main()
#         Select a device/interface and demonstrate.
#
# FILE
#     /home/virl/git/cosc-learning-labs/src/learning_lab/03_interface_configuration.py

# %% [markdown]
# ###Implementation

# %%
from importlib import import_module
script = import_module('learning_lab.03_interface_configuration')
from inspect import getsource
print(getsource(script.main))
# Out:
# def main():
#     ''' Select a device/interface and demonstrate.'''
#     print(plain(doc(interface_configuration)))
#     for device_name in inventory_connected():
#         mgmt_name = management_interface(device_name)
#         for interface_name in interface_names(device_name):
#             # Choose interface on 'data plane' not 'control plane'.
#             if interface_name == mgmt_name:
#                 continue
#             return demonstrate(device_name, interface_name)
#     print("There are no suitable network devices. Demonstration cancelled.")

# %%
print(getsource(script.demonstrate))
# Out:
# def demonstrate(device_name, interface_name):
#     ''' Apply function 'interface_configuration' to the specified device/interface.'''
#     print('interface_configuration(' + device_name, interface_name, sep=', ', end=')\n')
#     print_table(interface_configuration(device_name, interface_name))

# %% [markdown]
# ###Execution

# %%
run ../learning_lab/03_interface_configuration.py
# Out:
# Python Library Documentation: function interface_configuration in module basics.interface_configuration
#
# interface_configuration(device_name, interface_name)
#     Return a named tuple containing the information available for the specified interface of the specified, mounted device.
#
# interface_configuration(xrvr-511-53U, MgmtEth0/0/CPU0/0)
# <table>
# <tr><th>name</th><td>MgmtEth0/0/CPU0/0</td></tr>
# <tr><th>description</th><td>OOB Management</td></tr>
# <tr><th>shutdown</th><td>False</td></tr>
# <tr><th>address</th><td>172.16.1.84</td></tr>
# <tr><th>netmask</th><td>255.255.255.0</td></tr>
# <tr><th>ipv4_packet_filter_outbound</th><td>None</td></tr>
# <tr><th>ipv4_packet_filter_inbound</th><td>None</td></tr>
# <tr><th>active</th><td>act</td></tr>
# </table>

# %% [markdown]
# ###HTTP

# %%
from basics.odl_http import http_history
from basics.http import http_history_to_html
from IPython.core.display import HTML
HTML(http_history_to_html(http_history()))
# Out:
# <DIV>HTTP request/response: 1&nbsp;<A href="#http2">2</A>&nbsp;<A href="#http3">3</A>&nbsp;<A href="#http4">4</A>&nbsp;<BR id="http1"/><table>
#   <style>table {border: 1px solid black;}</style>
#   <style>tr:nth-of-type(even) {background-color:#eee;}</style>
#   <style>tr:nth-of-type(odd) {background-color:#fff;}</style>
#   <style>th {background-color:lightgray;}</style>
#   <thead>
#     <tr>
#       <th style="text-align:center" colspan="2">Request</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Method</th>
#       <td>GET</td>
#     </tr>
#     <tr>
#       <th>URL</th>
#       <td>http://127.0.0.1:8181/restconf/operational/opendaylight-inventory:nodes</td>
#     </tr>
#     <tr>
#       <th>Headers</th>
#       <td><table>
#     <tr>
#         <td>
#             Authorization
#         </td>
#         <td>
#             Basic YWRtaW46YWRtaW4=
#         </td>
#     </tr>
#     <tr>
#         <td>
#             User-Agent
#         </td>
#         <td>
#             python-requests/2.2.1 CPython/3.4.0 Linux/3.13.0-45-generic
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Accept
#         </td>
#         <td>
#             application/xml
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Accept-Encoding
#         </td>
#         <td>
#             gzip, deflate, compress
#         </td>
#     </tr>
#
# </table>
# </td>
#     </tr>
#     <tr>
#       <th>Content</th>
#       <td></td>
#     </tr>
#   </tbody>
#   <thead>
#       <tr>
#         <th style="text-align:center;background-color:white" colspan="2"/>
#       </tr>
#       <tr>
#         <th style="text-align:center" colspan="2">Response</th>
#       </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Status Code</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>Headers</th>
#       <td><table>
#     <tr>
#         <td>
#             transfer-encoding
#         </td>
#         <td>
#             chunked
#         </td>
#     </tr>
#     <tr>
#         <td>
#             content-type
#         </td>
#         <td>
#             application/xml
#         </td>
#     </tr>
#     <tr>
#         <td>
#             server
#         </td>
#         <td>
#             Jetty(8.1.14.v20131031)
#         </td>
#     </tr>
#
# </table>
# </td>
#     </tr>
#     <tr>
#       <th>Content</th>
#       <td><pre>&lt;?xml version='1.0' encoding='ASCII'?&gt;
# &lt;nodes xmlns="urn:opendaylight:inventory"&gt;
#   &lt;node&gt;
#     &lt;id&gt;xrvr-511-53U&lt;/id&gt;
#     &lt;connected xmlns="urn:opendaylight:netconf-node-inventory"&gt;true&lt;/connected&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-infra-statsd-cfg?revision=2013-07-22)Cisco-IOS-XR-infra-statsd-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-ifmib-cfg?revision=2013-07-22)Cisco-IOS-XR-snmp-ifmib-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ip-ntp-oper?revision=2013-07-22)Cisco-IOS-XR-ip-ntp-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ip-bfd-cfg?revision=2013-07-22)Cisco-IOS-XR-ip-bfd-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-oper?revision=2013-07-22)Cisco-IOS-XR-ifmgr-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-drivers-media-eth-cfg?revision=2013-07-22)Cisco-IOS-XR-drivers-media-eth-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg?revision=2013-07-22)Cisco-IOS-XR-shellutil-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-man-xml-ttyagent-cfg?revision=2013-07-22)Cisco-IOS-XR-man-xml-ttyagent-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-nd-cfg?revision=2013-07-22)Cisco-IOS-XR-ipv6-nd-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-acl-datatypes?revision=2013-07-22)Cisco-IOS-XR-ipv6-acl-datatypes&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-agent-oper?revision=2013-07-22)Cisco-IOS-XR-snmp-agent-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ip-iarm-datatypes?revision=2013-07-22)Cisco-IOS-XR-ip-iarm-datatypes&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-infra-alarm-logger-oper?revision=2013-07-22)Cisco-IOS-XR-infra-alarm-logger-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-l2-eth-infra-oper?revision=2013-07-22)Cisco-IOS-XR-l2-eth-infra-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-entitymib-cfg?revision=2013-07-22)Cisco-IOS-XR-snmp-entitymib-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ethernet-link-oam-cfg?revision=2013-07-22)Cisco-IOS-XR-ethernet-link-oam-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-arp-oper?revision=2013-07-22)Cisco-IOS-XR-ipv4-arp-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-cfg?revision=2013-07-22)Cisco-IOS-XR-infra-infra-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg?revision=2013-07-22)Cisco-IOS-XR-aaa-locald-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ip-bfd-oper?revision=2013-07-22)Cisco-IOS-XR-ip-bfd-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-cdp-oper?revision=2013-07-22)Cisco-IOS-XR-cdp-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-datatypes?revision=2013-07-22)Cisco-IOS-XR-ipv4-acl-datatypes&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ethernet-cfm-oper?revision=2013-07-22)Cisco-IOS-XR-ethernet-cfm-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-bundlemgr-oper?revision=2013-07-22)Cisco-IOS-XR-bundlemgr-oper&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-acl-cfg?revision=2013-07-22)Cisco-IOS-XR-ipv6-acl-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ip-tcp-cfg?revision=2013-07-22)Cisco-IOS-XR-ip-tcp-cfg&lt;/initial-capability&gt;
#     &lt;initial-capability xmlns="urn:opendaylight:netconf-node-inventory"&gt;(http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-cfg?revision=2013-07-22)Cisco-IOS-XR-ipv4-bgp-cfg&lt;/init
